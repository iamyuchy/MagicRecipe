# %% [markdown]
# ## Inverse Cooking: Recipe Generation from Food Images

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import os
from args import get_parser
import pickle
from model import get_model
from torchvision import transforms
from utils.output_utils import prepare_output
from PIL import Image
import time

# %% [markdown]
# Set ```data_dir``` to the path including vocabularies and model checkpoint

# %%
data_dir = ''

# %%
# code will run in gpu if available and if the flag is set to True, else it will run on cpu
use_gpu = True
device = torch.device('cuda' if torch.cuda.is_available() and use_gpu else 'cpu')
map_loc = None if torch.cuda.is_available() and use_gpu else 'cpu'


# device = torch.device('cpu')
# map_loc = None

# %%
print(device)
# Out:
# cuda

# %%
# code below was used to save vocab files so that they can be loaded without Vocabulary class
#ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_ingrs.pkl'), 'rb'))
#ingrs_vocab = [min(w, key=len) if not isinstance(w, str) else w for w in ingrs_vocab.idx2word.values()]
#vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_toks.pkl'), 'rb')).idx2word
#pickle.dump(ingrs_vocab, open('../demo/ingr_vocab.pkl', 'wb'))
#pickle.dump(vocab, open('../demo/instr_vocab.pkl', 'wb'))

ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'ingr_vocab.pkl'), 'rb'))
vocab = pickle.load(open(os.path.join(data_dir, 'instr_vocab.pkl'), 'rb'))

ingr_vocab_size = len(ingrs_vocab)
instrs_vocab_size = len(vocab)
output_dim = instrs_vocab_size

# %%
def get_ingrs(ids):
    gen_ingrs = []
    for ingr_idx in ids:
        ingr_name = ingrs_vocab[ingr_idx]
        if ingr_name == '<pad>':
            break
        if ingr_name == '<end>':
            break
        gen_ingrs.append(ingr_name)
    return gen_ingrs


def mask_from_eos(ids, eos_value, mult_before=True):
    mask = torch.ones(ids.size()).to(device).byte()
    mask_aux = torch.ones(ids.size(0)).to(device).byte()

    # find eos in ingredient prediction
    for idx in range(ids.size(1)):
        # force mask to have 1s in the first position to avoid division by 0 when predictions start with eos
        if idx == 0:
            continue
        if mult_before:
            mask[:, idx] = mask[:, idx] * mask_aux
            mask_aux = mask_aux * (ids[:, idx] != eos_value)
        else:
            mask_aux = mask_aux * (ids[:, idx] != eos_value)
            mask[:, idx] = mask[:, idx] * mask_aux
    return mask
print (instrs_vocab_size, ingr_vocab_size)
# Out:
# 23231 1488

# %%
t = time.time()
import sys; sys.argv=['']; del sys
args = get_parser()
args.maxseqlen = 15
args.ingrs_only=False
model = get_model(args, ingr_vocab_size, instrs_vocab_size)
# Load the trained model parameters
model_path = os.path.join('/home/ct2020dl5787/inversecooking/model/checkpoints', 'modelbest.ckpt')
model.load_state_dict(torch.load(model_path, map_location=map_loc))
model.to(device)
model.eval()
model.ingrs_only = False
model.recipe_only = False
model.reduction = 'none'
print ('loaded model')
print ("Elapsed time:", time.time() -t)
# Out:
# /home/ct2020dl5787/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# loaded model
# Elapsed time: 5.3432440757751465

# %% [markdown]
# Set ```use_urls = True``` to get recipes for images in ```demo_urls```.
#
# You can also set ```use_urls = False``` and get recipes for images in the path in ```data_dir/test_imgs```.

# %%
import requests
from io import BytesIO
import random
from collections import Counter
unpickled_df = pd.read_pickle("df_recipe1023.pkl")

use_urls = False # set to true to load images from demo_urls instead of those in test_imgs folder
show_anyways = False #if True, it will show the recipe even if it's not valid
image_folder = os.path.join('/home/ct2020dl5787/VireoFood172/sample_pictures1720')
#TODO1:load data
if not use_urls:
    demo_imgs = os.listdir(image_folder)
    random.shuffle(demo_imgs)

# demo_urls = ['https://food.fnr.sndimg.com/content/dam/images/food/fullset/2013/12/9/0/FNK_Cheesecake_s4x3.jpg.rend.hgtvcom.826.620.suffix/1387411272847.jpeg',
#          'https://www.196flavors.com/wp-content/uploads/2014/10/california-roll-3-FP.jpg']
demo_urls = unpickled_df["url"].tolist()
demo_files = demo_urls if use_urls else demo_imgs
# demo_files = demo_files

# %%
transf_list_batch = []
transf_list_batch.append(transforms.ToTensor())
transf_list_batch.append(transforms.Normalize((0.485, 0.456, 0.406), 
                                              (0.229, 0.224, 0.225)))
to_input_transf = transforms.Compose(transf_list_batch)

# %%
##STEP1: run image
err_pic = []
img_file_list = []
start = time.time()
for img_file in demo_files:
    
    if not use_urls and img_file.endswith(".jpg"):
        image_path = os.path.join(image_folder, img_file)
        image = Image.open(image_path).convert('RGB')

        transf_list = []
        transf_list.append(transforms.Resize(256))
        transf_list.append(transforms.CenterCrop(224))
        transform = transforms.Compose(transf_list)

        image_transf = transform(image)
        image_tensor = to_input_transf(image_transf).unsqueeze(0).to(device)

#         plt.imshow(image_transf)
#         plt.axis('off')
#         plt.show()
#         plt.close()

        num_valid = 1
        img_file_list.append(img_file)
        if img_file == demo_files[0]:
            print(img_file)
            image_all = image_tensor
        else:
             image_all = torch.cat((image_all,image_tensor))
# Out:
# 41_10_0.jpg

# %%
##step2: run ingredient_decoder  
## batch_size could be changed

outputs = dict()
recipt_all = []
batch_size = 100


for i in range(image_all.shape[0]//batch_size + 1):

    img_features = model.image_encoder(image_all[i*batch_size : (i+1)*batch_size])
    ingr_ids, ingr_probs = model.ingredient_decoder.sample(None,None,greedy = True,temperature=1.0,
                                                           img_features=img_features, first_token_value=0,replacement=False)
    
    sample_mask = mask_from_eos(ingr_ids, eos_value=0, mult_before=False)
    ingr_ids[sample_mask == 0] = 0

    outputs['ingr_ids'] = ingr_ids
    outputs['ingr_probs'] = ingr_probs.data

    ingr_ids = outputs['ingr_ids'].cpu().numpy()
    recipe = list(map(lambda x : get_ingrs(x), ingr_ids))
        
    recipt_all.extend(recipe)

# %%
print(len(recipt_all))
# Out:
# 1720

# %%
true_label_df = pd.read_pickle('/home/ct2020dl5787/VireoFood172/pickle_data/sample1720.pkl')

# %%
true_label_df
# Out:
#                           img_names                true_ingredients  \
# 0     92_075811n2tr1trtvr21vvao.jpg        [scallion, pepper, beef]
# 1     92_075817xlk22xxxagbk296x.jpg        [scallion, pepper, beef]
# 2                92_100053030.1.jpg        [scallion, pepper, beef]
# 3                       92_10_0.jpg                 [Parsley, beef]
# 4                       92_10_1.jpg  [Parsley, chili, garlic, beef]
# ...                             ...                             ...
# 1715                   63_10_14.jpg                   [tofu, chili]
# 1716                   63_10_16.jpg         [scallion, tofu, chili]
# 1717                   63_10_18.jpg   [scallion, pork, tofu, chili]
# 1718                   63_10_19.jpg        [scallion, pepper, tofu]
# 1719                    63_10_2.jpg         [scallion, tofu, chili]
#
#                                     ingredients_Chinese
# 0     [Minced green onion, Shredded pepper, Shredded...
# 1     [Minced green onion, Shredded pepper, Shredded...
# 2     [Minced green onion, Shredded pepper, Shredded...
# 3       [Chinese Parsleycoriander, Shredded beef tripe]
# 4     [Chinese Parsleycoriander, Crushed hot and dry...
# ...                                                 ...
# 1715                           [Tofu chunks, Chili oil]
# 1716       [Minced green onion, Tofu chunks, Chili oil]
# 1717  [Minced green onion, Minced pork, Tofu chunks,...
# 1718  [Minced green onion, Hot and dry pepper, Tofu ...
# 1719       [Minced green onion, Tofu chunks, Chili oil]
#
# [1720 rows x 3 columns]

# %%
generate_data = pd.DataFrame([img_file_list,recipt_all]).T
generate_data = generate_data.rename(columns={0: "img_names", 1: 'generate_ingre'})

# %%
all_info = pd.merge(true_label_df,generate_data, how='inner', on=['img_names'])
all_info.to_pickle('output/ingr_only_1720.pkl')
# Out:
#                           img_names                true_ingredients  \
# 0     92_075811n2tr1trtvr21vvao.jpg        [scallion, pepper, beef]
# 1     92_075817xlk22xxxagbk296x.jpg        [scallion, pepper, beef]
# 2                92_100053030.1.jpg        [scallion, pepper, beef]
# 3                       92_10_0.jpg                 [Parsley, beef]
# 4                       92_10_1.jpg  [Parsley, chili, garlic, beef]
# ...                             ...                             ...
# 1715                   63_10_14.jpg                   [tofu, chili]
# 1716                   63_10_16.jpg         [scallion, tofu, chili]
# 1717                   63_10_18.jpg   [scallion, pork, tofu, chili]
# 1718                   63_10_19.jpg        [scallion, pepper, tofu]
# 1719                    63_10_2.jpg         [scallion, tofu, chili]
#
#                                     ingredients_Chinese  \
# 0     [Minced green onion, Shredded pepper, Shredded...
# 1     [Minced green onion, Shredded pepper, Shredded...
# 2     [Minced green onion, Shredded pepper, Shredded...
# 3       [Chinese Parsleycoriander, Shredded beef tripe]
# 4     [Chinese Parsleycoriander, Crushed hot and dry...
# ...                                                 ...
# 1715                           [Tofu chunks, Chili oil]
# 1716       [Minced green onion, Tofu chunks, Chili oil]
# 1717  [Minced green onion, Minced pork, Tofu chunks,...
# 1718  [Minced green onion, Hot and dry pepper, Tofu ...
# 1719       [Minced green onion, Tofu chunks, Chili oil]
#
#                                          generate_ingre
# 0     [pepper, oil, onion, clove, soy_sauce, sugar, ...
# 1      [pepper, oil, onion, clove, beans, salt, tomato]
# 2     [pepper, onion, oil, chicken, mushroom, salt, ...
# 3     [pepper, oil, salt, potato, clove, onion, pars...
# 4     [oil, onion, pepper, soy_sauce, sugar, chicken...
# ...                                                 ...
# 1715  [onion, pepper, oil, chicken, clove, tomato, w...
# 1716  [onion, pepper, oil, soy_sauce, clove, broth, ...
# 1717  [onion, pepper, potato, clove, oil, tomato, sa...
# 1718  [onion, oil, soy_sauce, pepper, chicken, water...
# 1719  [onion, pepper, potato, oil, soy_sauce, water,...
#
# [1720 rows x 4 columns]

# %%
all_info[:50]
# Out:
#                                        img_names  \
# 0                  92_075811n2tr1trtvr21vvao.jpg
# 1                  92_075817xlk22xxxagbk296x.jpg
# 2                             92_100053030.1.jpg
# 3                                    92_10_0.jpg
# 4                                    92_10_1.jpg
# 5                                   92_10_10.jpg
# 6                                   92_10_11.jpg
# 7                                   92_10_16.jpg
# 8                                   92_10_17.jpg
# 9                                   92_10_24.jpg
# 10                         105_09-49-04-39-1.jpg
# 11                            105_0Q01231Y-0.jpg
# 12  105_0e2ca2b5-6870-4aa8-9b79-d60b8f161f0e.jpg
# 13                           105_100789721.1.jpg
# 14                           105_100860842.1.jpg
# 15                                  105_105a.jpg
# 16               105_10688781_091246617000_2.jpg
# 17                             105_1089358.1.jpg
# 18                                  105_10_0.jpg
# 19                                  105_10_1.jpg
# 20         149_01300534137870134686102049450.jpg
# 21              149_10398908623_03c343f5c8_z.jpg
# 22                             149_1052390.1.jpg
# 23                                  149_10_0.jpg
# 24                                  149_10_1.jpg
# 25                                 149_10_10.jpg
# 26                                 149_10_11.jpg
# 27                                 149_10_13.jpg
# 28                                 149_10_16.jpg
# 29                                 149_10_17.jpg
# 30                119_0013d350e0e80956a9ca0f.jpg
# 31       119_01300542520781139860132319415_s.jpg
# 32                                  119_1-10.jpg
# 33                      119_1-130331145632E3.jpg
# 34     119_1023173520071230145850406_005_640.jpg
# 35                                  119_10_0.jpg
# 36                                  119_10_1.jpg
# 37                                 119_10_10.jpg
# 38                                 119_10_11.jpg
# 39                                 119_10_13.jpg
# 40          49_01200000023782135247544658087.jpg
# 41          49_01200000023782135249151632931.jpg
# 42                        49_1-141205102R3J9.jpg
# 43                             49_1-5-11-527.jpg
# 44                                      49_1.jpg
# 45                                   49_10_1.jpg
# 46                                  49_10_15.jpg
# 47                                  49_10_18.jpg
# 48                                   49_10_2.jpg
# 49                                  49_10_25.jpg
#
#                                      true_ingredients  \
# 0                            [scallion, pepper, beef]
# 1                            [scallion, pepper, beef]
# 2                            [scallion, pepper, beef]
# 3                                     [Parsley, beef]
# 4                      [Parsley, chili, garlic, beef]
# 5                           [Parsley, cucumber, beef]
# 6                                      [pepper, beef]
# 7                                     [Parsley, beef]
# 8                  [diced_green_chilis, beef, celery]
# 9                  [diced_green_chilis, beef, celery]
# 10                    [black_sesame_seed, yam, sugar]
# 11  [black_sesame_seed, tomato, thin_cucumber_slic...
# 12                                       [yam, sugar]
# 13                                       [yam, sugar]
# 14                                       [yam, sugar]
# 15  [black_sesame_seed, tomato, thin_cucumber_slic...
# 16                              [yam, parsley, sugar]
# 17                                       [yam, sugar]
# 18                    [black_sesame_seed, yam, sugar]
# 19                                       [yam, sugar]
# 20                                         [scallion]
# 21                                         [scallion]
# 22                                         [scallion]
# 23                                         [scallion]
# 24                               [scallion, scallion]
# 25                                         [scallion]
# 26                                         [scallion]
# 27                                         [scallion]
# 28                                         [scallion]
# 29                                         [scallion]
# 30                     [dates, water, nuts, mushroom]
# 31                     [dates, water, nuts, mushroom]
# 32                     [dates, water, nuts, mushroom]
# 33                     [dates, water, nuts, mushroom]
# 34                   [spices, dates, water, mushroom]
# 35                     [dates, water, nuts, mushroom]
# 36  [dates, fresh_edible_flower, fruit, mint, wate...
# 37                           [dates, water, mushroom]
# 38                    [dates, fruit, water, mushroom]
# 39  [spices, dates, fresh_edible_flower, water, mu...
# 40                   [diced_green_chilis, egg, gourd]
# 41                                       [egg, gourd]
# 42                   [diced_green_chilis, egg, gourd]
# 43                                       [egg, gourd]
# 44                                       [egg, gourd]
# 45                   [diced_green_chilis, egg, gourd]
# 46                   [diced_green_chilis, egg, gourd]
# 47                                       [egg, gourd]
# 48                                       [egg, gourd]
# 49                                       [egg, gourd]
#
#                                   ingredients_Chinese  \
# 0   [Minced green onion, Shredded pepper, Shredded...
# 1   [Minced green onion, Shredded pepper, Shredded...
# 2   [Minced green onion, Shredded pepper, Shredded...
# 3     [Chinese Parsleycoriander, Shredded beef tripe]
# 4   [Chinese Parsleycoriander, Crushed hot and dry...
# 5   [Chinese Parsleycoriander, Julienned cucumber,...
# 6                [Pepper slices, Shredded beef tripe]
# 7     [Chinese Parsleycoriander, Shredded beef tripe]
# 8       [Crushed pepper, Shredded beef tripe, Celery]
# 9       [Crushed pepper, Shredded beef tripe, Celery]
# 10          [Black sesame, Yam chunks, Crystal sugar]
# 11  [Black sesame, Cherry tomato slices, Cucumber ...
# 12                        [Yam chunks, Crystal sugar]
# 13                        [Yam chunks, Crystal sugar]
# 14                        [Yam chunks, Crystal sugar]
# 15  [Black sesame, Cherry tomato slices, Cucumber ...
# 16               [Yam chunks, Parsley, Crystal sugar]
# 17                        [Yam chunks, Crystal sugar]
# 18          [Black sesame, Yam chunks, Crystal sugar]
# 19                        [Yam chunks, Crystal sugar]
# 20                                 [Scallion pancake]
# 21                                 [Scallion pancake]
# 22                                 [Scallion pancake]
# 23                                 [Scallion pancake]
# 24             [Minced green onion, Scallion pancake]
# 25                                 [Scallion pancake]
# 26                                 [Scallion pancake]
# 27                                 [Scallion pancake]
# 28                                 [Scallion pancake]
# 29                                 [Scallion pancake]
# 30      [Red dates, Water, Lotus seeds, White fungus]
# 31      [Red dates, Water, Lotus seeds, White fungus]
# 32      [Red dates, Water, Lotus seeds, White fungus]
# 33      [Red dates, Water, Lotus seeds, White fungus]
# 34        [Wolfberry, Red dates, Water, White fungus]
# 35      [Red dates, Water, Lotus seeds, White fungus]
# 36  [Red dates, Lilium brownii, Longan, Mint leaf,...
# 37                   [Red dates, Water, White fungus]
# 38           [Red dates, Longan, Water, White fungus]
# 39  [Wolfberry, Red dates, Lilium brownii, Water, ...
# 40            [Crushed pepper, Scrambled egg, Loofah]
# 41                            [Scrambled egg, Loofah]
# 42            [Crushed pepper, Scrambled egg, Loofah]
# 43                            [Scrambled egg, Loofah]
# 44                            [Scrambled egg, Loofah]
# 45            [Crushed pepper, Scrambled egg, Loofah]
# 46            [Crushed pepper, Scrambled egg, Loofah]
# 47                            [Scrambled egg, Loofah]
# 48                            [Scrambled egg, Loofah]
# 49                            [Scrambled egg, Loofah]
#
#                                        generate_ingre
# 0   [pepper, oil, onion, clove, soy_sauce, sugar, ...
# 1    [pepper, oil, onion, clove, beans, salt, tomato]
# 2   [pepper, onion, oil, chicken, mushroom, salt, ...
# 3   [pepper, oil, salt, potato, clove, onion, pars...
# 4   [oil, onion, pepper, soy_sauce, sugar, chicken...
# 5        [pepper, oil, onion, salt, soy_sauce, clove]
# 6   [oil, pepper, onion, clove, soy_sauce, ginger,...
# 7   [onion, soy_sauce, sugar, sake, water, mirin, ...
# 8   [oil, pepper, soy_sauce, clove, onion, ginger,...
# 9   [oil, pepper, soy_sauce, clove, onion, sugar, ...
# 10      [soy_sauce, sugar, sake, oil, mirin, chicken]
# 11                        [potato, pepper, oil, salt]
# 12                              [sugar, butter, salt]
# 13          [oil, salt, sugar, potato, pepper, onion]
# 14  [oil, potato, salt, soy_sauce, pepper, onion, ...
# 15                        [potato, oil, pepper, salt]
# 16                        [sugar, egg, milk, extract]
# 17            [sugar, butter, cinnamon, potato, salt]
# 18                  [sugar, butter, soy_sauce, honey]
# 19        [oil, pepper, shrimp, salt, clove, ketchup]
# 20             [salt, oil, flour, water, egg, pepper]
# 21  [cheese, onion, pepper, tortilla, egg, flour, ...
# 22             [salt, flour, cheese, egg, onion, oil]
# 23  [salt, flour, water, egg, baking_powder, milk,...
# 24  [salt, flour, water, yeast, sugar, egg, butter...
# 25  [salt, flour, water, egg, milk, oil, baking_po...
# 26  [cheese, egg, pepper, onion, zucchini, salt, m...
# 27         [cheese, onion, pepper, egg, butter, salt]
# 28                     [egg, flour, salt, onion, oil]
# 29  [sugar, flour, salt, egg, yeast, water, milk, ...
# 30                              [sugar, milk, banana]
# 31                    [sugar, milk, juice, pineapple]
# 32                    [water, sugar, cherries, juice]
# 33                                [rice, milk, sugar]
# 34             [water, rice, milk, sugar, katakuriko]
# 35       [beans, rice, grapes, water, raisins, sugar]
# 36                              [water, sugar, apple]
# 37                        [strawberries, pepper, oil]
# 38                             [sugar, butter, water]
# 39  [onion, pepper, beans, water, salt, apple, car...
# 40       [pepper, oil, onion, salt, soy_sauce, clove]
# 41    [oil, chicken, pepper, soy_sauce, water, onion]
# 42     [oil, pepper, onion, avocado, salt, pineapple]
# 43             [oil, pepper, butter, salt, soy_sauce]
# 44  [oil, pepper, soy_sauce, clove, butter, salt, ...
# 45  [oil, pepper, onion, soy_sauce, salt, katakuri...
# 46  [oil, cucumber, seeds, soy_sauce, pepper, onio...
# 47           [pepper, oil, butter, salt, peas, clove]
# 48       [oil, pepper, onion, water, soy_sauce, salt]
# 49                    [oil, pepper, soy_sauce, juice]

# %%
##step3:save info
generate_data = pd.DataFrame([img_file_list,recipt_all]).T
generate_data = generate_data.rename(columns={0: "url", 1: "generate_ingre"})
all_info = pd.merge(unpickled_df, generate_data , how='inner', on=['url'])
all_info.to_pickle('output/recipt_only.pkl')
all_info.head()
# Out:
# Empty DataFrame
# Columns: [id, ingredients, instructions, url, generate_ingre]
# Index: []

# %%
##step4:evalutation
def get_ingred_f1(pred, label):
    '''
    input: 
        pred: a list of predicted ingredients
        label: a list of label ingredients
    output: 
        F-1 score of the prediction
    
    i.e.  
    in: 
        pred = ["tomato", "sugar", "beef"]
        label = ["potato", "tomato"]
     
    out: 
        0.4
    '''
    intersection = list(set(pred) & set(label))
    precision = len(intersection) / len(pred)
    recall = len(intersection) / len(label)
    f1 = 2 * precision * recall / (precision + recall)
    return f1


def get_ingred_IOU(pred, label):
    '''
    input: 
        pred: a list of predicted ingredients
        label: a list of label ingredients
    output: 
        IOU of the prediction
    
    i.e.  
    in: 
        pred = ["tomato", "sugar", "beef"]
        label = ["potato", "tomato"]
     
    out: 
        0.25
    '''
    intersection = len(list(set(pred) & set(label)))
    union = len(list(set(pred) | set(label)))
    iou = intersection / union
    return iou


import nltk
import string
def get_bleu_n_score(pred, label, n = 4):
    
    '''
    TODO: STEM not added
    input: 
        pred: One string of predict recipe 
        label: One string of reference recipe
        n(optional): up to n-gram.
    output: 
        bleu score
    
    i.e.  
    in: 
        pred = "Add the buttter"
        label = "Add half butter and mix well"
    out: 
        0.25
    '''
    weights = [1/n] * n
    pred_list = pred.translate(str.maketrans('', '', string.punctuation)).split()
    label_list = label.translate(str.maketrans('', '', string.punctuation)).split()
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([label_list], pred_list, weights)
    return BLEUscore



from nltk.translate.meteor_score import meteor_score
def get_meteor_score(pred, label):
    return meteor_score([label], pred)
