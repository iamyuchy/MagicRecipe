# %% [markdown]
# ## Inverse Cooking: Recipe Generation from Food Images

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import os
from args import get_parser
import pickle
from model import get_model
from torchvision import transforms
from utils.output_utils import prepare_output
from PIL import Image
import time
from shutil import copyfile
import csv

# %% [markdown]
# Set ```data_dir``` to the path including vocabularies and model checkpoint

# %%
########move data to sample data folder

selected_files = []
rootdir = '/home/ct2020dl5787/VireoFood172/ready_chinese_food'
for subdir, dirs, files in os.walk(rootdir):
    
    if(len(files) > 0):
        file_name = sorted(files)[0]
        prefix = subdir.split("/")[-1]
        
        selected_files.append(prefix + "/" + file_name)

print(len(selected_files))

##############################
# Out:
# 172

# %%
selected_files[0]
# Out:
# '92/075811n2tr1trtvr21vvao.jpg'

# %%
copydir = '/home/ct2020dl5787/VireoFood172/sample_pictures'
for eachfile in selected_files:
    file_name = eachfile.replace("/", "_")
    ori = os.path.join(rootdir, eachfile)
    dst = os.path.join(copydir, file_name)
    copyfile(ori, dst)

# %%
vocab_file = '/home/ct2020dl5787/VireoFood172/vocab172_mapping.csv'
chinese_vocab = []
mapped_vocab = []
with open(vocab_file) as file:
    csv_reader = csv.reader(file, delimiter=',')
    for row in csv_reader:
        #check duplicate
        chinese_vocab.append(row[0])
        mapped_vocab.append(row[1])
        #print("originally: ", row[0], " mapped to ", row[1])

# %%
true_labels = dict()
ing_labels_file = open('/home/ct2020dl5787/VireoFood172/SplitAndIngreLabel/IngreLabel.txt', 'r')
contents = ing_labels_file.readlines()
for line in contents:
    filename = line.split()[0]
    labels = line.split()[1:]
    true_labels[filename] = labels
ing_labels_file.close()

# %%
img_names = []
img_ingre = []
img_chinese_ingre = []
for f in selected_files:
    name = "/"+f
    if name not in true_labels:
        print("error")
    else :
        binary_label = true_labels[name]
        mapped_labels = []
        mapped_chinese_labels = []
        for index, label in enumerate(binary_label):
            if(label == "1") :
                mapped_labels.append(mapped_vocab[index])
                mapped_chinese_labels.append(chinese_vocab[index])
        
        img_ingre.append(mapped_labels)
        img_chinese_ingre.append(mapped_chinese_labels)
        img_names.append(f.replace("/", "_"))

# %%
img_dict = {'img_names': img_names, 'true_ingredients': img_ingre, 'ingredients_Chinese' : img_chinese_ingre}  
    
true_label_df = pd.DataFrame(img_dict)

# %%
true_label_df
# Out:
#                                    img_names  \
# 0              92_075811n2tr1trtvr21vvao.jpg
# 1                      105_09-49-04-39-1.jpg
# 2      149_01300534137870134686102049450.jpg
# 3             119_0013d350e0e80956a9ca0f.jpg
# 4       49_01200000023782135247544658087.jpg
# ..                                       ...
# 167         26_-14a0b3561215bc87dbb-7d8b.jpg
# 168            41_0023ae99e1440e9a332d05.jpg
# 169    164_01300000245880122362433364658.jpg
# 170  89_07c47c849ee611e3b4a6e0db5512b209.jpg
# 171   63_01300000326808123012566498554_s.jpg
#
#                             true_ingredients  \
# 0                   [scallion, pepper, beef]
# 1            [black_sesame_seed, yam, sugar]
# 2                                 [scallion]
# 3             [dates, water, nuts, mushroom]
# 4           [diced_green_chilis, egg, gourd]
# ..                                       ...
# 167                       [chicken, parsley]
# 168                  [scallion, shrimp, egg]
# 169                  [chicken, water, herbs]
# 170          [scallion, egg, seaweed, water]
# 171  [korean_red_pepper_powder, tofu, chili]
#
#                                    ingredients_Chinese
# 0    [Minced green onion, Shredded pepper, Shredded...
# 1            [Black sesame, Yam chunks, Crystal sugar]
# 2                                   [Scallion pancake]
# 3        [Red dates, Water, Lotus seeds, White fungus]
# 4              [Crushed pepper, Scrambled egg, Loofah]
# ..                                                 ...
# 167                           [Chicken Wings, Parsley]
# 168  [Minced green onion, Dried sea shrimp, Steamed...
# 169  [Whole black chicken, Water, Codonopsis pilosula]
# 170       [Minced green onion, Egg drop, Laver, Water]
# 171  [Hot and dry pepper powder, Tofu chunks, Chili...
#
# [172 rows x 3 columns]

# %%
# code will run in gpu if available and if the flag is set to True, else it will run on cpu
use_gpu = True
device = torch.device('cuda' if torch.cuda.is_available() and use_gpu else 'cpu')
map_loc = None if torch.cuda.is_available() and use_gpu else 'cpu'


# device = torch.device('cpu')
# map_loc = None

# %%
print(device)
# Out:
# cuda

# %%
# code below was used to save vocab files so that they can be loaded without Vocabulary class
#ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_ingrs.pkl'), 'rb'))
#ingrs_vocab = [min(w, key=len) if not isinstance(w, str) else w for w in ingrs_vocab.idx2word.values()]
#vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_toks.pkl'), 'rb')).idx2word
#pickle.dump(ingrs_vocab, open('../demo/ingr_vocab.pkl', 'wb'))
#pickle.dump(vocab, open('../demo/instr_vocab.pkl', 'wb'))
data_dir = ""
ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'ingr_vocab.pkl'), 'rb'))
vocab = pickle.load(open(os.path.join(data_dir, 'instr_vocab.pkl'), 'rb'))

ingr_vocab_size = len(ingrs_vocab)
instrs_vocab_size = len(vocab)
output_dim = instrs_vocab_size

# %%
#print(ingrs_vocab)

# %%
print (instrs_vocab_size, ingr_vocab_size)
# Out:
# 23231 1488

# %%
t = time.time()
import sys; sys.argv=['']; del sys
args = get_parser()
args.maxseqlen = 15
args.ingrs_only=False
model = get_model(args, ingr_vocab_size, instrs_vocab_size)
# Load the trained model parameters
model_path = os.path.join('/home/ct2020dl5787/inversecooking/model/checkpoints', 'modelbest.ckpt')
model.load_state_dict(torch.load(model_path, map_location=map_loc))
model.to(device)
model.eval()
model.ingrs_only = False
model.recipe_only = False
model.reduction = 'none'
print ('loaded model')
print ("Elapsed time:", time.time() -t)
# Out:
# /home/ct2020dl5787/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# loaded model
# Elapsed time: 3.86720609664917

# %%
transf_list_batch = []
transf_list_batch.append(transforms.ToTensor())
transf_list_batch.append(transforms.Normalize((0.485, 0.456, 0.406), 
                                              (0.229, 0.224, 0.225)))
to_input_transf = transforms.Compose(transf_list_batch)

# %%
greedy = [True, False, False, False]
beam = [-1, -1, -1, -1]
temperature = 1.0
numgens = len(greedy)

# %% [markdown]
# Set ```use_urls = True``` to get recipes for images in ```demo_urls```.
#
# You can also set ```use_urls = False``` and get recipes for images in the path in ```data_dir/test_imgs```.

# %%
import requests
from io import BytesIO
import random
from collections import Counter
unpickled_df = pd.read_pickle("df_recipe1023.pkl")
use_urls = False # set to true to load images from demo_urls instead of those in test_imgs folder
show_anyways = False #if True, it will show the recipe even if it's not valid
image_folder = os.path.join('/home/ct2020dl5787/VireoFood172/sample_pictures')
#TODO1:load data
if not use_urls:
    demo_imgs = os.listdir(image_folder)
    random.shuffle(demo_imgs)

demo_urls = ['https://food.fnr.sndimg.com/content/dam/images/food/fullset/2013/12/9/0/FNK_Cheesecake_s4x3.jpg.rend.hgtvcom.826.620.suffix/1387411272847.jpeg',
         'https://www.196flavors.com/wp-content/uploads/2014/10/california-roll-3-FP.jpg']
demo_urls = unpickled_df["url"].tolist()
demo_files = demo_urls if use_urls else demo_imgs

demo_files = demo_files

# %%
for img_file in demo_files:
    if not img_file.endswith(".jpg"):
        print(img_file)

# %%
info_all = []
err_pic = []
start = time.time()
for img_file in demo_files:
    
    if not use_urls and img_file.endswith(".jpg"):
#         response = requests.get(img_file)
#         try:
#             image = Image.open(BytesIO(response.content))
        image_path = os.path.join(image_folder, img_file)
        image = Image.open(image_path).convert('RGB')

        transf_list = []
        transf_list.append(transforms.Resize(256))
        transf_list.append(transforms.CenterCrop(224))
        transform = transforms.Compose(transf_list)

        image_transf = transform(image)
        image_tensor = to_input_transf(image_transf).unsqueeze(0).to(device)

       # plt.imshow(image_transf)
       # plt.axis('off')
      #  plt.show()
      #  plt.close()

        num_valid = 1

        generate_ing = []
        generate_recipt = []
        generate_title = []
        generate_score = []
        for i in range(numgens):
            with torch.no_grad():
                outputs = model.sample(image_tensor, greedy=greedy[i],temperature=temperature, beam=beam[i], true_ingrs=None)
            ingr_ids = outputs['ingr_ids'].cpu().numpy()
            recipe_ids = outputs['recipe_ids'].cpu().numpy()

            outs, valid = prepare_output(recipe_ids[0], ingr_ids[0], ingrs_vocab, vocab)
            #TODO2: Save output  
            generate_ing.append(outs['ingrs'])
            generate_recipt.append(outs['recipe'])
            generate_title.append(outs['title'])
            generate_score.append([valid['is_valid'],valid['score']])

#             if valid['is_valid'] or show_anyways:

#                 print ('RECIPE', num_valid)
#                 num_valid+=1
#                 #print ("greedy:", greedy[i], "beam:", beam[i])

#                 BOLD = '\033[1m'
#                 END = '\033[0m'
#                 print (BOLD + '\nTitle:' + END,outs['title'])

#                 print (BOLD + '\nIngredients:'+ END)
#                 print (', '.join(outs['ingrs']))

#                 print (BOLD + '\nInstructions:'+END)
#                 print ('-'+'\n-'.join(outs['recipe']))

#                 print ('='*20)

#             else:
#                 pass
#                 print ("Not a valid recipe!")
#                 print ("Reason: ", valid['reason'])
        info_all.append([img_file,generate_ing, generate_recipt,generate_title,generate_score])
    #except:
     
        #pass
        
print(start-time.time())
# Out:
# -2170.8469870090485

# %%
# Out:
#                                    img_names  \
# 0              92_075811n2tr1trtvr21vvao.jpg
# 1                      105_09-49-04-39-1.jpg
# 2      149_01300534137870134686102049450.jpg
# 3             119_0013d350e0e80956a9ca0f.jpg
# 4       49_01200000023782135247544658087.jpg
# ..                                       ...
# 167         26_-14a0b3561215bc87dbb-7d8b.jpg
# 168            41_0023ae99e1440e9a332d05.jpg
# 169    164_01300000245880122362433364658.jpg
# 170  89_07c47c849ee611e3b4a6e0db5512b209.jpg
# 171   63_01300000326808123012566498554_s.jpg
#
#                                       true_ingredients
# 0                          [scallion, pepper, spinach]
# 1                    [black_sesame_seed, yam, cashews]
# 2                                               [rice]
# 3                            [kiwi, nuts, beans, fish]
# 4                      [diced_green_chilis, egg, fish]
# ..                                                 ...
# 167                                       [peas, duck]
# 168                            [scallion, shrimp, egg]
# 169                             [chicken, nuts, herbs]
# 170  [scallion, egg, refrigerated_cornbread_twists_...
# 171       [korean_red_pepper_powder, bean_curd, chili]
#
# [172 rows x 2 columns]

# %%
generate_data = pd.DataFrame(info_all,columns = ['img_names','generate_ingre','generate_reci','generate_title','generate_score'])
all_info = pd.merge(true_label_df, generate_data , how='inner', on=['img_names'])

# %%
all_info
# Out:
#                                    img_names  \
# 0              92_075811n2tr1trtvr21vvao.jpg
# 1                      105_09-49-04-39-1.jpg
# 2      149_01300534137870134686102049450.jpg
# 3             119_0013d350e0e80956a9ca0f.jpg
# 4       49_01200000023782135247544658087.jpg
# ..                                       ...
# 167         26_-14a0b3561215bc87dbb-7d8b.jpg
# 168            41_0023ae99e1440e9a332d05.jpg
# 169    164_01300000245880122362433364658.jpg
# 170  89_07c47c849ee611e3b4a6e0db5512b209.jpg
# 171   63_01300000326808123012566498554_s.jpg
#
#                             true_ingredients  \
# 0                   [scallion, pepper, beef]
# 1            [black_sesame_seed, yam, sugar]
# 2                                 [scallion]
# 3             [dates, water, nuts, mushroom]
# 4           [diced_green_chilis, egg, gourd]
# ..                                       ...
# 167                       [chicken, parsley]
# 168                  [scallion, shrimp, egg]
# 169                  [chicken, water, herbs]
# 170          [scallion, egg, seaweed, water]
# 171  [korean_red_pepper_powder, tofu, chili]
#
#                                    ingredients_Chinese  \
# 0    [Minced green onion, Shredded pepper, Shredded...
# 1            [Black sesame, Yam chunks, Crystal sugar]
# 2                                   [Scallion pancake]
# 3        [Red dates, Water, Lotus seeds, White fungus]
# 4              [Crushed pepper, Scrambled egg, Loofah]
# ..                                                 ...
# 167                           [Chicken Wings, Parsley]
# 168  [Minced green onion, Dried sea shrimp, Steamed...
# 169  [Whole black chicken, Water, Codonopsis pilosula]
# 170       [Minced green onion, Egg drop, Laver, Water]
# 171  [Hot and dry pepper powder, Tofu chunks, Chili...
#
#                                         generate_ingre  \
# 0    [[pepper, oil, onion, clove, soy_sauce, sugar,...
# 1    [[soy_sauce, sugar, sake, oil, mirin, chicken]...
# 2    [[salt, oil, flour, water, egg, pepper], [salt...
# 3    [[sugar, milk, banana], [sugar, milk, banana],...
# 4    [[pepper, oil, onion, salt, soy_sauce, clove],...
# ..                                                 ...
# 167  [[sugar, egg, butter, milk, extract], [sugar, ...
# 168  [[milk, sugar, onion, pepper, butter, salt, fl...
# 169  [[water, salt, butter, sugar], [water, salt, b...
# 170  [[soy_sauce, sugar, seaweed, salt, mirin], [so...
# 171  [[pepper, onion, tomato, clove, oil, salt, bas...
#
#                                          generate_reci  \
# 0    [[Heat oil in a large skillet over medium heat...
# 1    [[Cut the chicken wings into bite-sized pieces...
# 2    [[In a large bowl, mix together the flour, sal...
# 3    [[In a medium saucepan, combine the milk, suga...
# 4    [[Heat oil in a wok or large skillet over medi...
# ..                                                 ...
# 167  [[In a medium saucepan, combine the sugar, but...
# 168  [[Melt butter in a large saucepan over medium ...
# 169  [[In a medium saucepan, combine the peanut but...
# 170  [[Rehydrate the hijiki seaweed in water., Drai...
# 171  [[Heat olive oil in a large skillet over mediu...
#
#                                         generate_title  \
# 0    [Spicy bean stir-fry, Stir-fried vegetables an...
# 1    [Teriyaki chicken wings, Delicious simmered sa...
# 2    [Easy homemade pasta, Homemade pancake, Homema...
# 3    [Banana pudding, Banana ice cream, Microwaved ...
# 4    [Stir-fried peppers and onions, Quick garlic s...
# ..                                                 ...
# 167  [Easy caramel sauce, Baked vanilla pound cake,...
# 168  [Creamy onion soup, Creamy green onion soup mi...
# 169  [Peanut butter sauce, Hot water, Caramel sauce...
# 170  [Hijiki seaweed and aburaage, Hijiki seaweed w...
# 171  [Tomato basil sauce, Easy tomato marinara sauc...
#
#                                         generate_score
# 0    [[True, 0.5], [True, 0.5540540540540541], [Tru...
# 1    [[True, 0.5918367346938775], [True, 0.58490566...
# 2    [[True, 0.603448275862069], [True, 0.625], [Tr...
# 3    [[True, 0.6229508196721312], [True, 0.63953488...
# 4    [[True, 0.543859649122807], [True, 0.626666666...
# ..                                                 ...
# 167  [[True, 0.6346153846153846], [True, 0.62337662...
# 168  [[True, 0.5376344086021505], [True, 0.48148148...
# 169  [[True, 0.5769230769230769], [True, 0.57142857...
# 170  [[True, 0.45977011494252873], [True, 0.5581395...
# 171  [[True, 0.6142857142857143], [True, 0.56790123...
#
# [172 rows x 7 columns]

# %%
all_info.to_pickle('chinese172sample_allinfo.pkl')

# %%
#TODO3: Evaluation

# %%
generate_data.to_pickle('output/generate_172sample.pkl')

# %%
def get_ingred_f1(pred, label):
    '''
    input: 
        pred: a list of predicted ingredients
        label: a list of label ingredients
    output: 
        F-1 score of the prediction
    
    i.e.  
    in: 
        pred = ["tomato", "sugar", "beef"]
        label = ["potato", "tomato"]
     
    out: 
        0.4
    '''
    intersection = list(set(pred) & set(label))
    precision = len(intersection) / len(pred)
    recall = len(intersection) / len(label)
    f1 = 2 * precision * recall / (precision + recall)
    return f1


def get_ingred_IOU(pred, label):
    '''
    input: 
        pred: a list of predicted ingredients
        label: a list of label ingredients
    output: 
        IOU of the prediction
    
    i.e.  
    in: 
        pred = ["tomato", "sugar", "beef"]
        label = ["potato", "tomato"]
     
    out: 
        0.25
    '''
    intersection = len(list(set(pred) & set(label)))
    union = len(list(set(pred) | set(label)))
    iou = intersection / union
    return iou


import nltk
import string
def get_bleu_n_score(pred, label, n = 4):
    
    '''
    TODO: STEM not added
    input: 
        pred: One string of predict recipe 
        label: One string of reference recipe
        n(optional): up to n-gram.
    output: 
        bleu score
    
    i.e.  
    in: 
        pred = "Add the buttter"
        label = "Add half butter and mix well"
    out: 
        0.25
    '''
    weights = [1/n] * n
    pred_list = pred.translate(str.maketrans('', '', string.punctuation)).split()
    label_list = label.translate(str.maketrans('', '', string.punctuation)).split()
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([label_list], pred_list, weights)
    return BLEUscore



from nltk.translate.meteor_score import meteor_score
def get_meteor_score(pred, label):
    return meteor_score([label], pred)

# %%
for row in range(len(all_info)):
    print(all_info.loc[row, "true_ingredients"])
# Out:
# ['scallion', 'pepper', 'spinach']
# ['black_sesame_seed', 'yam', 'cashews']
# ['rice']
# ['kiwi', 'nuts', 'beans', 'fish']
# ['diced_green_chilis', 'egg', 'fish']
# ['chili', 'squid', 'celery']
# ['scallion', 'clam', 'bean_curd', 'nuts']
# ['diced_green_chilis', 'ketchup']
# ['scallion', 'steak', 'cheese', 'wonton']
# ['pork', 'startch']
# ['Parsley', 'chicken', 'duck']
# ['egg']
# ['Parsley', 'pork', 'vermicelli']
# ['soybeans']
# ['greens', 'chicken']
# ['pepper', 'egg']
# ['chili', 'pork', 'beans']
# ['diced_green_chilis', 'egg']
# ['tomato', 'lemon', 'beef']
# ['chives', 'korean_red_pepper_powder', 'chili']
# ['thin_cucumber_slices', 'egg', 'mango']
# ['diced_green_chilis', 'dried_black_fungus']
# ['carrot', 'spices', 'crabmeat']
# ['ham', 'carrot', 'cucumber', 'egg', 'meatballs', 'greens']
# ['clam', 'fish']
# ['roll']
# ['greens', 'chili', 'squid']
# ['chives', 'egg']
# ['peas', 'chicken']
# ['diced_green_chilis', 'pork', 'greens']
# ['lettuce', 'duck']
# ['Parsley', 'pepper', 'zucchini']
# ['garlic']
# ['scallion', 'crayfish', 'chili']
# ['scallion', 'chili', 'pork', 'garlic']
# ['scallion', 'ham', 'corn', 'cucumber', 'meatballs', 'pickled_daikon', 'pork']
# ['scallion', 'bean_curd', 'egg']
# ['black_sesame_seed', 'rice', 'fish']
# ['onion', 'bok_choy', 'duck']
# ['scallion', 'rice']
# ['Parsley', 'cucumber', 'chili', 'fresh_lotus_root']
# ['scallion', 'bread', 'stew_beef_chunk', 'beef']
# ['garlic', 'bamboo_shoot']
# ['scallion', 'fish', 'fish']
# ['diced_green_chilis', 'pork', 'mushroom']
# ['Parsley', 'shrimp', 'chili']
# ['pepper', 'Parsley', 'sweet_and_sour_sauce']
# ['scallion', 'garlic', 'clam']
# ['cabbage', 'pickled_daikon']
# ['cucumber', 'yam', 'orange', 'pig']
# ['scallion', 'Parsley', 'stew_beef_chunk', 'beef', 'chili', 'radish']
# ['egg', 'chestnut']
# ['scallion', 'diced_green_chilis', 'pork']
# ['pork']
# ['carrot', 'meatballs', 'eggplant', 'pork']
# ['scallion', 'stew_beef_chunk', 'nuts', 'duck']
# ['greens', 'chicken']
# ['noodles']
# ['pepper', 'pork']
# ['diced_green_chilis', 'corn', 'other_pastas', 'pork']
# ['pepper', 'pork', 'meatballs', 'millet']
# ['pepper', 'pork', 'sprouts']
# ['bitter_melons', 'garlic']
# ['pepper', 'pork']
# ['bay_leaf']
# ['scallion', 'black_sesame_seed', 'pepper', 'egg', 'fish']
# ['scallion', 'tea']
# ['bread', 'gluten']
# ['Parsley', 'cucumber', 'garlic']
# ['scallion', 'pork', 'pickle', 'egg', 'spaghetti']
# ['carrot', 'Parsley', 'bread', 'garlic', 'chicken', 'tenderloin']
# ['scallion', 'pork', 'beans']
# ['pepper', 'chili', 'cabbage']
# ['scallion', 'grapes']
# ['scallion', 'chili', 'spareribs', 'vermicelli']
# ['scallion', 'chili', 'pork', 'chili']
# ['stir_-_fry_sauce']
# ['egg']
# ['pepper', 'frozen_potato_slices', 'chicken']
# ['carrot', 'greens', 'corn', 'onion', 'banana', 'soybeans']
# ['crispbread', 'mango']
# ['cucumber', 'egg', 'egg']
# ['Parsley', 'peanuts', 'chili', 'chicken']
# ['soybean_paste']
# ['scallion', 'asparagus', 'meatballs']
# ['chili', 'eggplant', 'beans']
# ['cucumber', 'chili', 'mutton']
# ['dry_coconut_powder']
# ['diced_green_chilis', 'seaweed', 'noodles']
# ['sweet_and_sour_sauce']
# ['peanuts', 'chili', 'squid', 'duck']
# ['scallion', 'pork']
# ['pepper', 'pork', 'garlic', 'eggplant']
# ['chicken']
# ['tomato', 'egg']
# ['pepper', 'frozen_potato_slices', 'eggplant']
# ['diced_green_chilis', 'Parsley', 'chicken']
# ['Parsley', 'chili', 'chili', 'fish']
# ['diced_green_chilis', 'Parsley', 'seaweed']
# ['scallion', 'diced_green_chilis', 'chili', 'flour']
# ['diced_green_chilis', 'Parsley', 'caviar']
# ['scallion', 'potato']
# ['diced_green_chilis', 'cherries']
# ['Parsley', 'fresh_lotus_root', 'clam', 'noodles', 'nuts']
# ['diced_green_chilis', 'Parsley', 'kale']
# ['pepper', 'greens', 'potato']
# ['pepper', 'cucumber', 'bean_curd']
# ['meatballs', 'beef', 'frozen_potato_slices']
# ['diced_green_chilis', 'shrimp', 'pickle', 'celery']
# ['shrimp', 'fresh_edible_flower', 'lemongrass', 'nuts']
# ['diced_green_chilis', 'bean_curd', 'parsley']
# ['scallion', 'peanuts', 'chili', 'sesame', 'duck', 'vermicelli']
# ['scallion', 'beans', 'macaroni']
# ['toast', 'cumin']
# ['mushroom', 'asparagus']
# ['pepper']
# ['beef']
# ['pepper', 'mushroom', 'chicken']
# ['scallion', 'black_sesame_seed', 'korean_red_pepper_powder', 'eggplant']
# ['pepper', 'bean_curd']
# ['onion', 'beef', 'pepper']
# ['scallion', 'pepper', 'egg', 'asparagus', 'meatballs', 'beans', 'scallion']
# ['bean_curd', 'nuts', 'vinegar']
# ['scallion', 'diced_green_chilis', 'garlic', 'water', 'beans']
# ['chicken']
# ['peanuts']
# ['scallion', 'pepper', 'pork', 'cling_peach_halves']
# ['carrot', 'thin_cucumber_slices', 'dried_black_fungus', 'egg', 'pork']
# ['scallion', 'diced_green_chilis', 'pork', 'chinese_duck_sauce']
# ['breadstick', 'bean_paste']
# ['diced_green_chilis', 'Parsley', 'dried_black_fungus', 'okra', 'celery']
# ['peanuts', 'pepper', 'garlic', 'caviar', 'fresh_lotus_root', 'greens']
# ['dried_black_fungus', 'bread', 'chili', 'sesame', 'pork', 'bean_curd', 'salad_dressing']
# ['scallion', 'black_sesame_seed', 'bean_curd', 'egg']
# ['diced_green_chilis', 'tofu', 'nuts']
# ['scallion', 'pork', 'scallops']
# ['greens', 'mutton', 'bread', 'beans']
# ['shrimp', 'chicken']
# ['scallion', 'stew_beef_chunk', 'beef', 'nuts']
# ['scallion', 'carrot', 'dried_black_fungus', 'stew_beef_chunk']
# ['meatballs']
# ['scallion', 'black_sesame_seed', 'chili', 'spinach', 'sausage']
# ['pepper', 'potato']
# ['squid']
# ['peas', 'chicken']
# ['black_sesame_seed', 'pepper', 'Parsley', 'onion', 'mutton']
# ['scallion', 'fresh_lotus_root']
# ['black_sesame_seed', 'meatballs', 'noodles', 'rice']
# ['bread', 'spareribs']
# ['breadstick']
# ['diced_green_chilis', 'noodles']
# ['scallion', 'chili', 'zucchini']
# ['ginger', 'chicken']
# ['scallion', 'pepper', 'Parsley', 'chili', 'mushroom']
# ['stew_beef_chunk', 'chinese_duck_sauce']
# ['bitter_melons', 'egg']
# ['meatballs', 'pork']
# ['greens']
# ['greens', 'chicken', 'chicken', 'pig']
# ['soymilk']
# ['Parsley', 'pepper', 'fresh_edible_flower']
# ['nuts', 'mushroom']
# ['scallion', 'diced_green_chilis', 'cauliflower']
# ['duck', 'buns']
# ['chili', 'pork', 'cabbage']
# ['pork', 'sprouts']
# ['diced_green_chilis', 'Parsley', 'spinach']
# ['peas', 'duck']
# ['scallion', 'shrimp', 'egg']
# ['chicken', 'nuts', 'herbs']
# ['scallion', 'egg', 'refrigerated_cornbread_twists_dough', 'nuts']
# ['korean_red_pepper_powder', 'bean_curd', 'chili']
