# %% [markdown]
# ## Inverse Cooking: Recipe Generation from Food Images

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import os
from args import get_parser
import pickle
from model import get_model
from torchvision import transforms
from utils.output_utils import prepare_output
from PIL import Image
import time

# %% [markdown]
# Set ```data_dir``` to the path including vocabularies and model checkpoint

# %%
data_dir = ''

# %%
# code will run in gpu if available and if the flag is set to True, else it will run on cpu
use_gpu = True
device = torch.device('cuda' if torch.cuda.is_available() and use_gpu else 'cpu')
map_loc = None if torch.cuda.is_available() and use_gpu else 'cpu'


# device = torch.device('cpu')
# map_loc = None

# %%
print(device)
# Out:
# cuda

# %%
# code below was used to save vocab files so that they can be loaded without Vocabulary class
#ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_ingrs.pkl'), 'rb'))
#ingrs_vocab = [min(w, key=len) if not isinstance(w, str) else w for w in ingrs_vocab.idx2word.values()]
#vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_toks.pkl'), 'rb')).idx2word
#pickle.dump(ingrs_vocab, open('../demo/ingr_vocab.pkl', 'wb'))
#pickle.dump(vocab, open('../demo/instr_vocab.pkl', 'wb'))

ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'ingr_vocab.pkl'), 'rb'))
vocab = pickle.load(open(os.path.join(data_dir, 'instr_vocab.pkl'), 'rb'))

ingr_vocab_size = len(ingrs_vocab)
instrs_vocab_size = len(vocab)
output_dim = instrs_vocab_size

# %%
print (instrs_vocab_size, ingr_vocab_size)
# Out:
# 23231 1488

# %%
t = time.time()
import sys; sys.argv=['']; del sys
args = get_parser()
args.maxseqlen = 15
args.ingrs_only=False
model = get_model(args, ingr_vocab_size, instrs_vocab_size)
# Load the trained model parameters
model_path = os.path.join('/home/ct2020dl5787/inversecooking/model/checkpoints', 'modelbest.ckpt')
model.load_state_dict(torch.load(model_path, map_location=map_loc))
model.to(device)
model.eval()
model.ingrs_only = False
model.recipe_only = False
model.reduction = 'none'
print ('loaded model')
print ("Elapsed time:", time.time() -t)
# Out:
# loaded model
# Elapsed time: 2.5223464965820312

# %%
transf_list_batch = []
transf_list_batch.append(transforms.ToTensor())
transf_list_batch.append(transforms.Normalize((0.485, 0.456, 0.406), 
                                              (0.229, 0.224, 0.225)))

to_input_transf = transforms.Compose(transf_list_batch)

# %%
greedy = [True, False, False, False]
beam = [-1, -1, -1, -1]
temperature = 1.0
numgens = len(greedy)

# %% [markdown]
# Set ```use_urls = True``` to get recipes for images in ```demo_urls```.
#
# You can also set ```use_urls = False``` and get recipes for images in the path in ```data_dir/test_imgs```.

# %%
import requests
from io import BytesIO
import random
from collections import Counter
unpickled_df = pd.read_pickle("df_recipe1023.pkl")
use_urls = True # set to true to load images from demo_urls instead of those in test_imgs folder
show_anyways = False #if True, it will show the recipe even if it's not valid
image_folder = os.path.join('/home/ct2020dl5787/inversecooking/data/'+'demo_imgs')
#TODO1:load data
# if not use_urls:
#     demo_imgs = os.listdir(image_folder)
#     random.shuffle(demo_imgs)

# demo_urls = ['https://food.fnr.sndimg.com/content/dam/images/food/fullset/2013/12/9/0/FNK_Cheesecake_s4x3.jpg.rend.hgtvcom.826.620.suffix/1387411272847.jpeg',
#          'https://www.196flavors.com/wp-content/uploads/2014/10/california-roll-3-FP.jpg']
demo_urls = unpickled_df["url"].tolist()
demo_files = demo_urls if use_urls else demo_imgs
# demo_files = demo_files

# %%
err_pic = []
img_file_list = []
start = time.time()
for img_file in demo_files:
    
#    if use_urls:
    response = requests.get(img_file)
    try:
        image = Image.open(BytesIO(response.content))
    
        transf_list = []
        transf_list.append(transforms.Resize(256))
        transf_list.append(transforms.CenterCrop(224))
        transform = transforms.Compose(transf_list)

        image_transf = transform(image)
        image_tensor = to_input_transf(image_transf).unsqueeze(0).to(device)
        
#         plt.imshow(image_transf)
#         plt.axis('off')
#         plt.show()
#         plt.close()
        
        num_valid = 1
        img_file_list.append(img_file)
        if img_file == demo_files[0]:
            print(img_file)
            image_all = image_tensor
        else:
             image_all = torch.cat((image_all,image_tensor))
    except:
        print('error image')
        pass
test2 = torch.cat((test,image_tensor))
# Out:
# http://img.sndimg.com/food/image/upload/w_512,h_512,c_fit,fl_progressive,q_95/v1/img/recipes/47/91/49/picaYYmb9.jpg

# %%
image_all = image_all.to(device)
model.sample(image_all[:2],greedy=greedy[i],temperature=temperature, beam=beam[i], true_ingrs=True)

# %%
info_all = []
err_pic = []
start = time.time()
for img_file in demo_files:
    
#    if use_urls:
    response = requests.get(img_file)
    try:
        image = Image.open(BytesIO(response.content))
    
            
#     else:
#         image_path = os.path.join(image_folder, img_file)
#         image = Image.open(image_path).convert('RGB')

        transf_list = []
        transf_list.append(transforms.Resize(256))
        transf_list.append(transforms.CenterCrop(224))
        transf_list.append(transforms.RandomRotation(30))
        transform = transforms.Compose(transf_list)

        image_transf = transform(image)
        image_tensor = to_input_transf(image_transf).unsqueeze(0).to(device)

#         plt.imshow(image_transf)
#         plt.axis('off')
#         plt.show()
#         plt.close()

        num_valid = 1

        generate_ing = []
        generate_recipt = []
        generate_title = []
        generate_score = []
        for i in range(numgens):
            with torch.no_grad():
                outputs = model.sample(image_tensor, greedy=greedy[i],temperature=temperature, beam=beam[i], true_ingrs=None)
            ingr_ids = outputs['ingr_ids'].cpu().numpy()
            recipe_ids = outputs['recipe_ids'].cpu().numpy()

            outs, valid = prepare_output(recipe_ids[0], ingr_ids[0], ingrs_vocab, vocab)
            #TODO2: Save output  
            generate_ing.append(outs['ingrs'])
            generate_recipt.append(outs['recipe'])
            generate_title.append(outs['title'])
            generate_score.append([valid['is_valid'],valid['score']])

#             if valid['is_valid'] or show_anyways:

#                 print ('RECIPE', num_valid)
#                 num_valid+=1
#                 #print ("greedy:", greedy[i], "beam:", beam[i])

#                 BOLD = '\033[1m'
#                 END = '\033[0m'
#                 print (BOLD + '\nTitle:' + END,outs['title'])

#                 print (BOLD + '\nIngredients:'+ END)
#                 print (', '.join(outs['ingrs']))

#                 print (BOLD + '\nInstructions:'+END)
#                 print ('-'+'\n-'.join(outs['recipe']))

#                 print ('='*20)

#             else:
#                 pass
#                 print ("Not a valid recipe!")
#                 print ("Reason: ", valid['reason'])
        info_all.append([img_file,generate_ing, generate_recipt,generate_title,generate_score])
    except:
        pass
        
print(time.time()-start)

# %%
generate_data = pd.DataFrame(info_all,columns = ['url','generate_ingre','generate_reci','generate_title','generate_score'])
all_info = pd.merge(unpickled_df, generate_data , how='inner', on=['url'])
all_info.to_pickle('output/roatation.pkl')

# %%
info_all = []
err_pic = []
start = time.time()
for img_file in demo_files:
    
#    if use_urls:
    response = requests.get(img_file)
    try:
        image = Image.open(BytesIO(response.content))
    
            
#     else:
#         image_path = os.path.join(image_folder, img_file)
#         image = Image.open(image_path).convert('RGB')

        transf_list = []
        transf_list.append(transforms.Resize(256))
        transf_list.append(transforms.CenterCrop(224))
        transf_list.append(transforms.RandomHorizontalFlip(p=1))
        transform = transforms.Compose(transf_list)

        image_transf = transform(image)
        image_tensor = to_input_transf(image_transf).unsqueeze(0).to(device)

        plt.imshow(image_transf)
        plt.axis('off')
        plt.show()
        plt.close()

        num_valid = 1

        generate_ing = []
        generate_recipt = []
        generate_title = []
        generate_score = []
        for i in range(numgens):
            with torch.no_grad():
                outputs = model.sample(image_tensor, greedy=greedy[i],temperature=temperature, beam=beam[i], true_ingrs=None)
            ingr_ids = outputs['ingr_ids'].cpu().numpy()
            recipe_ids = outputs['recipe_ids'].cpu().numpy()

            outs, valid = prepare_output(recipe_ids[0], ingr_ids[0], ingrs_vocab, vocab)
            #TODO2: Save output  
            generate_ing.append(outs['ingrs'])
            generate_recipt.append(outs['recipe'])
            generate_title.append(outs['title'])
            generate_score.append([valid['is_valid'],valid['score']])

            if valid['is_valid'] or show_anyways:

                print ('RECIPE', num_valid)
                num_valid+=1
                #print ("greedy:", greedy[i], "beam:", beam[i])

                BOLD = '\033[1m'
                END = '\033[0m'
                print (BOLD + '\nTitle:' + END,outs['title'])

                print (BOLD + '\nIngredients:'+ END)
                print (', '.join(outs['ingrs']))

                print (BOLD + '\nInstructions:'+END)
                print ('-'+'\n-'.join(outs['recipe']))

                print ('='*20)

            else:
                pass
                print ("Not a valid recipe!")
                print ("Reason: ", valid['reason'])
        info_all.append([img_file,generate_ing, generate_recipt,generate_title,generate_score])
    except:
        pass
        
print(start-time.time())
# Out:
# RECIPE 1
#
# Title: Cheesy hash browns casserole
#
# Ingredients:
# cheese, onion, pepper, soup, milk, salt, butter, cream
#
# Instructions:
# -Preheat oven to 350 degrees f (175 degrees c).
# -Grease a 9x13-inch baking dish.
# -Melt butter in a skillet over medium heat; cook and stir onion in melted butter until translucent, 5 to 7 minutes.
# -Stir hash browns, cheddar cheese, sour cream, cheddar cheese, cream of chicken soup, milk, salt, and black pepper into onion; pour into prepared baking dish.
# -Bake in the preheated oven until hash browns are tender, about 1 hour.
# ====================
# RECIPE 2
#
# Title: Creamy baked potatoes
#
# Ingredients:
# cheese, onion, pepper, soup, milk, salt, butter, cream
#
# Instructions:
# -Place potatoes in greased 13 x 9 baking dish.
# -Sprinkle with onions and cheeses.
# -Whisk remaining ingredients except for topping until well blended.
# -Pour over potatoes and sprinkle with topping.
# -Cover and bake at 350 for 1 hour.
# -Uncover and bake 30 minutes longer.
# ====================
# RECIPE 3
#
# Title: Cheesy rotel dip
#
# Ingredients:
# cheese, onion, pepper, soup, milk, salt, butter, cream
#
# Instructions:
# -Melt butter in a medium saucepan over medium heat.
# -Add onions, and saute until tender, about 4 minutes.
# -Remove from heat, and stir in cheese.
# -Mix in condensed cream of mushroom soup, milk, and sour cream.
# -Add salt and pepper to taste.
# -Pour into a greased 8x8 baking dish.
# -Bake at 350 degrees f for 45 minutes.
# ====================
# RECIPE 4
#
# Title: Baked potato soup
#
# Ingredients:
# cheese, onion, pepper, soup, milk, salt, butter, cream
#
# Instructions:
# -Mix all ingredients together, except butter and cheese and bake at 350 for 1 hour.
# -Top with grated cheese and bake 5 more minutes.
# ====================
# RECIPE 1
#
# Title: Lemon chicken
#
# Ingredients:
# chicken, pepper, salt, lemon, oil, onion, juice
#
# Instructions:
# -Preheat oven to 350 degrees f (175 degrees c).
# -Place chicken in a 9x13 inch baking dish.
# -In a small bowl, combine lemon juice, olive oil, salt, pepper, and onion powder.
# -Pour mixture over chicken.
# -Bake in preheated oven for 1 hour, or until chicken is no longer pink and juices run clear.
# ====================
# RECIPE 2
#
# Title: Lemon garlic roast chicken
#
# Ingredients:
# chicken, pepper, salt, lemon, oil, onion, juice
#
# Instructions:
# -Preheat oven to 425 degrees f (220 degrees c).
# -Combine onion, lemon juice, lemon zest, oil, salt and pepper in a large resealable plastic bag.
# -Add chicken, seal bag, and turn to coat.
# -Arrange chicken in a single layer on a roasting pan.
# -Bake in preheated oven until the chicken is no longer pink in the center, about 45 minutes; turn the chicken, basting every 15 minutes with pan juices every 10 minutes, until juices run clear when an instant-read meat thermometer inserted into the thickest part of the thigh reads 180 degrees f (82 degrees c).
# -Transfer chicken to a cutting board, cover loosely, and let rest for 15 minutes before carving and serving.
# ====================
# RECIPE 3
#
# Title: Lemon pepper chicken
#
# Ingredients:
# chicken, pepper, salt, lemon, oil, onion, juice
#
# Instructions:
# -In small bowl, combine olive oil, lemon juice, onion, salt and pepper.
# -Place chicken breasts between sheets of plastic wrap, and pound with flat side of meat mallet or rolling pin until 1/2 inch thick.
# -In a large, shallow dish, mix together marinade ingredients.
# -Pour marinade evenly over chicken in dish.
# -Turn to coat chicken well, cover and refrigerate for at least one hour, or overnight.
# -Place chicken on grill over medium-high heat.
# -Cook until done, about 20 minutes.
# -Turn and cook for 10 minutes more.
# ====================
# RECIPE 4
#
# Title: Lemon chicken
#
# Ingredients:
# chicken, pepper, salt, lemon, oil, onion, juice
#
# Instructions:
# -In a medium bowl, mix together the first 5 ingredients until the salt and pepper are dissolved.
# -Place the chicken pieces in the bowl, and toss with the salt mixture to coat.
# -Heat a large skillet over medium high heat.
# -Add the chicken to the pan; cook for about 5 minutes, turning once to brown evenly on both sides.
# -Serve immediately.
# ====================
# RECIPE 1
#
# Title: Strawberry rhubarb pie
#
# Ingredients:
# sugar, strawberries, water, egg, rhubarb, salt, flour
#
# Instructions:
# -Preheat oven to 350 degrees f (175 degrees c).
# -Grease a 9-inch pie plate.
# -In a large bowl, mix together the rhubarb, strawberries, sugar, flour, and salt.
# -Pour into the prepared pie plate.
# -In a separate bowl, beat together the egg and water.
# -Pour over the rhubarb mixture.
# -Bake in the preheated oven for 45 minutes, or until a knife inserted into the center of the pie comes out clean.
# ====================
# RECIPE 2
#
# Title: Strawberry rhubarb custard pie
#
# Ingredients:
# sugar, strawberries, water, egg, rhubarb, salt, flour
#
# Instructions:
# -Preheat the oven to 375 degrees f.
# -In a large bowl, combine the rhubarb, strawberries, sugar, and water.
# -Stir to mix well.
# -In another bowl, combine all the flours, brown sugar and salt.
# -Stir the wet ingredients into the dry.
# -Mix well.
# -Pour the mixture into the pie crust.
# -Bake for 50-60 minutes or until a knife inserted in the center comes out clean.
# -Let cool for at least one hour, then serve.
# ====================
# Not a valid recipe!
# Reason:  no eos found
# Not a valid recipe!
# Reason:  no eos found
# RECIPE 1
#
# Title: Berry parfait
#
# Ingredients:
# strawberries, yogurt, blueberries, honey, almonds, sugar
#
# Instructions:
# -Layer half each of the strawberries, blueberries, and almonds in a parfait glass.
# -Repeat layers.
# -Top with yogurt and honey.
# ====================
# RECIPE 2
#
# Title: Berry parfait with yogurt
#
# Ingredients:
# strawberries, yogurt, blueberries, honey, almonds, sugar
#
# Instructions:
# -Place 1/2 cup yogurt in a blender; cover and blend until smooth.
# -Transfer 1/4 cup yogurt to a bowl; repeat procedure with remaining yogurt.
# -Spoon 1/4 cup yogurt into each of four parfait glasses; top each with 1/2 cup strawberries and 2/3 cup blueberries.
# -Sprinkle each parfait with 1 tablespoon almonds and 1 tablespoon brown sugar.
# ====================
# RECIPE 3
#
# Title: Yogurt fruit parfait
#
# Ingredients:
# strawberries, yogurt, blueberries, honey, almonds, sugar
#
# Instructions:
# -In a medium bowl, toss the strawberries with 1/2 cup of sugar and let stand for 10 minutes.
# -In parfait glass, layer half of each of the strawberries, yogurt, blueberries, and almonds.
# -Repeat layers, ending with granola.
# ====================
# RECIPE 4
#
# Title: Fresh fruit parfait
#
# Ingredients:
# strawberries, yogurt, blueberries, honey, almonds, sugar
#
# Instructions:
# -In a medium bowl, combine the yogurt with the honey and stir until smooth.
# -Set aside.
# -In a parfait glass, layer 1/4 cup of granola, 1/2 of blueberries, 1/4 cup yogurt mixture and 1/2 cup of sliced almonds.
# -Repeat layers.
# -Cover and refrigerate for at least 30 minutes before serving.
# -Serve.
# ====================
# RECIPE 1
#
# Title: Roasted potatoes with herbs
#
# Ingredients:
# oil, pepper, potato, clove, salt, rosemary, parsley, thyme
#
# Instructions:
# -Preheat oven to 425 degrees f.
# -In a large bowl, toss potatoes with olive oil, garlic, parsley, thyme, rosemary, salt and pepper.
# -Spread potatoes in a single layer on a baking sheet.
# -Roast for 30 minutes, stirring once halfway through.
# ====================
# RECIPE 2
#
# Title: Roasted new potatoes with rosemary & thyme
#
# Ingredients:
# oil, pepper, potato, clove, salt, rosemary, parsley, thyme
#
# Instructions:
# -Heat oven to 425f.
# -In small bowl, combine oil, herbs, salt and pepper.
# -Place potatoes in a large bowl, and toss with oil mixture.
# -Transfer to a large, rimmed baking sheet.
# -Roast until potatoes are tender and golden, turning occasionally, about 35 minutes.
# -Remove from sheet and let stand 10 minutes.
# ====================
# RECIPE 3
#
# Title: Herb roasted potatoes
#
# Ingredients:
# oil, pepper, potato, clove, salt, rosemary, parsley, thyme
#
# Instructions:
# -Preheat oven to 425f.
# -Toss potatoes with herbs and garlic in a large bowl; drizzle with olive oil.
# -Toss well to coat.
# -Place potatoes in roasting pan.
# -Place pan on middle rack of oven; roast, turning potatoes occasionally, until potatoes are tender and browned in spots, about 45 minutes.
# -Season with salt and pepper and serve.
# ====================
# RECIPE 4
#
# Title: Herbed roast potatoes
#
# Ingredients:
# oil, pepper, potato, clove, salt, rosemary, parsley, thyme
#
# Instructions:
# -Place potatoes in a large pot, and add enough cold water to cover the potatoes by 2 inches.
# -Boil until potatoes are tender, approximately 30 to 40 minutes.
# -Drain potatoes and return to pot.
# -Add oil, garlic, herbs, salt, and pepper.
# -Mash potatoes with a potato masher until smooth, and evenly combined.
# ====================
# RECIPE 1
#
# Title: Orange and lemon sangria
#
# Ingredients:
# orange, juice, water, ice, lemon
#
# Instructions:
# -In a large pitcher, combine the orange juice, lemon juice, orange juice, and water.
# -Stir in the ice cubes.
# -Serve in tall glasses over ice.
# ====================
# RECIPE 2
#
# Title: Orange lemonade
#
# Ingredients:
# orange, juice, water, ice, lemon
#
# Instructions:
# -Combine the water, juice, lemon juice and the sweetand low in a pitcher.
# -Stir until dissolved then stir in the ice.
# -Serve over ice, garnished with orange slices.
# ====================
# RECIPE 3
#
# Title: Orange lemonade
#
# Ingredients:
# orange, juice, water, ice, lemon
#
# Instructions:
# -Place orange juice concentrate, lemon juice, and water in a pitcher and stir until combined.
# -Serve in tall glasses over ice garnished with orange slices.
# ====================
# RECIPE 4
#
# Title: Aperol spritz
#
# Ingredients:
# orange, juice, water, ice, lemon
#
# Instructions:
# -Pour the aperol into the glass with ice cubes.
# -Squeeze the juice from the meyer lemons into a glass, then drop in the seltzer.
# -Garnish with the orange slices, if desired.
# ====================
# RECIPE 1
#
# Title: Teriyaki sauce
#
# Ingredients:
# sugar, soy_sauce, water, sake, oil, mirin
#
# Instructions:
# -Combine all ingredients in a small saucepan.
# -Bring to a boil, reduce heat and simmer for 5 minutes.
# ====================
# RECIPE 2
#
# Title: Teriyaki sauce for bento
#
# Ingredients:
# sugar, soy_sauce, water, sake, oil, mirin
#
# Instructions:
# -Combine the ingredients.
# -Coat the meat and it's done.
# ====================
# RECIPE 3
#
# Title: Teriyaki marinade
#
# Ingredients:
# sugar, soy_sauce, water, sake, oil, mirin
#
# Instructions:
# -Mix all the ingredients together.
# -Marinade for a minimum of 1 hour or overnight.
# ====================
# RECIPE 4
#
# Title: Easy simmered satsuma-age
#
# Ingredients:
# sugar, soy_sauce, water, sake, oil, mirin
#
# Instructions:
# -Cut the satsuma-age into suitable lengths.
# -Cut into easy-to-eat pieces.
# -Combine all the ingredients and simmer until the liquid has evaporated.
# -Once cooled, pour into a pan and let cool.
# -Done !
# ====================
# RECIPE 1
#
# Title: Hamburger casserole
#
# Ingredients:
# cheese, onion, pepper, beef, egg, milk, salt
#
# Instructions:
# -Brown ground beef and onion.
# -Drain.
# -Add salt, pepper, and garlic salt.
# -Add eggs and milk.
# -Mix well.
# -Add cheese.
# -Pour into a greased casserole dish.
# -Bake at 350 for 30 minutes.
# ====================
# RECIPE 2
#
# Title: Beef casserole
#
# Ingredients:
# cheese, onion, pepper, beef, egg, milk, salt
#
# Instructions:
# -Brown meat and onions.
# -Add salt and pepper, and then add milk, eggs, cheese and green chilies.
# -Mix well and put in casserole dish.
# -Bake at 325f for 1 hour.
# -Note: this is best when made with a double recipe.
# -I've tried this in my crock pot with the meat and it worked in.
# -I am always the night before.
# ====================
# RECIPE 3
#
# Title: Cheeseburger casserole
#
# Ingredients:
# cheese, onion, pepper, beef, egg, milk, salt
#
# Instructions:
# -Heat oven to 350.
# -Grease 9 x 13 pan.
# -In a large bowl, combine ground beef, salt, pepper and onion, and egg.
# -Press into ungreased dish.
# -Bake for 30 minutes or until lightly browned.
# -Meanwhile, in another large skillet, cook green bell pepper until tender.
# -Drain off grease.
# -Add cream cheese and cook and stir over low heat until cheese is melted.
# -Stir in milk and green onions.
# -Spread over ground beef mixture and bake for 20 minutes longer or until heated through.
# -Let stand 5 minutes before serving.
# ====================
# RECIPE 4
#
# Title: Beef casserole
#
# Ingredients:
# cheese, onion, pepper, beef, egg, milk, salt
#
# Instructions:
# -Fry the beef until the beef is browned.
# -Mix in the salt and pepper.
# -Add the onion, soup and milk.
# -Mix all together.
# -Put in a greased casserole.
# -Top with a sprinkle of cheese.
# -Bake at 350 for about 30 minutes.
# ====================
# RECIPE 1
#
# Title: Broccoli casserole
#
# Ingredients:
# cheese, onion, pepper, broccoli, salt, milk, cream, butter
#
# Instructions:
# -Preheat oven to 350 degrees f (175 degrees c).
# -Grease a 9x13 inch baking dish.
# -In a large bowl, combine broccoli, onion, sour cream, milk, salt and pepper.
# -Mix well and pour into prepared baking dish.
# -In a small bowl, combine melted butter and parmesan cheese.
# -Sprinkle over broccoli mixture.
# -Bake in preheated oven for 30 minutes, or until heated through.
# ====================
# RECIPE 2
#
# Title: Creamy broccoli cheese pie
#
# Ingredients:
# cheese, onion, pepper, broccoli, salt, milk, cream, butter
#
# Instructions:
# -Preheat oven to 375 degrees f (190 degrees c).
# -Melt butter in a large skillet over medium-high heat.
# -Cook and stir broccoli, onion, salt, and black pepper in the melted butter until vegetables are tender, 5 to 7 minutes; transfer vegetables to a large bowl.
# -Stir sour cream, cheddar cheese, and milk into the broccoli mixture until well combined.
# -Pour cream mixture evenly into the bottom of a 9-inch pie dish.
# -Place the cheddar cheese on top of the broccoli mixture.
# -Bake in preheated oven until hot and bubbling, about 45 minutes.
# ====================
# RECIPE 3
#
# Title: Broccoli cheese casserole
#
# Ingredients:
# cheese, onion, pepper, broccoli, salt, milk, cream, butter
#
# Instructions:
# -Combine first 4 ingredients in a large bowl.
# -Stir in broccoli and cheese.
# -Spoon into a greased 1-quart baking dish.
# -Combine crushed pepper and melted butter; sprinkle over broccoli mixture.
# -Bake at 350f for 35-40 minutes or until bubbly.
# ====================
# RECIPE 4
#
# Title: Broccoli and cheese casserole
#
# Ingredients:
# cheese, onion, pepper, broccoli, salt, milk, cream, butter
#
# Instructions:
# -Steam broccoli for 5 min or until almost tender.
# -Mix together soup, sour cream, milk and salt; set aside.
# -In a greased 9x13 baking dish layer broccoli, cheese and onion.
# -Pour soup mixture over all.
# -Dot with butter and sprinkle with salt and pepper.
# -Bake at 350 for 25-30 min or until cheese is melted and bubbly.
# ====================
# RECIPE 1
#
# Title: Peanut butter and soy sauce
#
# Ingredients:
# oil, butter, sugar, soy_sauce
#
# Instructions:
# -Mix all ingredients together.
# -Serve with your favorite meal.
# ====================
# RECIPE 2
#
# Title: Peanut butter dip
#
# Ingredients:
# oil, butter, sugar, soy_sauce
#
# Instructions:
# -Combine peanut butter and powdered sugar in a bowl.
# -Gradually add soy sauce and stir to combine.
# -Use as a dip for veggies or pretzels, or as dipping sauce (as a dipping sauce).
# ====================
# RECIPE 3
#
# Title: Peanut butter dip
#
# Ingredients:
# oil, butter, sugar, soy_sauce
#
# Instructions:
# -In small bowl, stir together peanut butter, canola oil, soy sauce and sugar.
# -Serve with sliced fruit.
# ====================
# RECIPE 4
#
# Title: Fried peanut sauce - easy and delicious !
#
# Ingredients:
# oil, butter, sugar, soy_sauce
#
# Instructions:
# -Mix all the ingredients.
# -Put in a bowl.
# -Use as a dipping sauce for fish, or chicken.
# ====================
# -121.94398641586304

# %%
generate_data = pd.DataFrame(info_all,columns = ['url','generate_ingre','generate_reci','generate_title','generate_score'])
all_info = pd.merge(unpickled_df, generate_data , how='inner', on=['url'])
all_info.to_pickle('output/transform.pkl')

# %%
#TODO3: Evaluation

# %%
generate_data.to_pickle('output/generate_1000_backup.pkl')

# %%
def get_ingred_f1(pred, label):
    '''
    input: 
        pred: a list of predicted ingredients
        label: a list of label ingredients
    output: 
        F-1 score of the prediction
    
    i.e.  
    in: 
        pred = ["tomato", "sugar", "beef"]
        label = ["potato", "tomato"]
     
    out: 
        0.4
    '''
    intersection = list(set(pred) & set(label))
    precision = len(intersection) / len(pred)
    recall = len(intersection) / len(label)
    f1 = 2 * precision * recall / (precision + recall)
    return f1


def get_ingred_IOU(pred, label):
    '''
    input: 
        pred: a list of predicted ingredients
        label: a list of label ingredients
    output: 
        IOU of the prediction
    
    i.e.  
    in: 
        pred = ["tomato", "sugar", "beef"]
        label = ["potato", "tomato"]
     
    out: 
        0.25
    '''
    intersection = len(list(set(pred) & set(label)))
    union = len(list(set(pred) | set(label)))
    iou = intersection / union
    return iou


import nltk
import string
def get_bleu_n_score(pred, label, n = 4):
    
    '''
    TODO: STEM not added
    input: 
        pred: One string of predict recipe 
        label: One string of reference recipe
        n(optional): up to n-gram.
    output: 
        bleu score
    
    i.e.  
    in: 
        pred = "Add the buttter"
        label = "Add half butter and mix well"
    out: 
        0.25
    '''
    weights = [1/n] * n
    pred_list = pred.translate(str.maketrans('', '', string.punctuation)).split()
    label_list = label.translate(str.maketrans('', '', string.punctuation)).split()
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([label_list], pred_list, weights)
    return BLEUscore



from nltk.translate.meteor_score import meteor_score
def get_meteor_score(pred, label):
    return meteor_score([label], pred)
